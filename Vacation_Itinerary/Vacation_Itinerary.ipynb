# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head(50)
# Out:
#     City_ID                  City Country  Max Temp Weather Description  \
# 0         0           Meadow Lake      US     63.61          few clouds
# 1         2            Nelson Bay      AU     68.00       broken clouds
# 2         4            Bredasdorp      ZA     62.28     overcast clouds
# 3        15              Victoria      HK     62.58       broken clouds
# 4        16        Port Macquarie      AU     66.16     overcast clouds
# 5        22             Cape Town      ZA     66.34     overcast clouds
# 6        29                  Lebu      CL     60.28     overcast clouds
# 7        30         Mar Del Plata      AR     60.87     overcast clouds
# 8        31                 Airai      TL     61.72       moderate rain
# 9        40                Hobart      AU     60.03     overcast clouds
# 10       44                 Kifri      IQ     65.19     overcast clouds
# 11       45               Chhatak      BD     68.18          few clouds
# 12       59                Lawton      US     68.47           clear sky
# 13       62         Alice Springs      AU     67.55           clear sky
# 14       63              Hermanus      ZA     63.90     overcast clouds
# 15       68              Gopalpur      IN     69.62          few clouds
# 16       71               Mildura      AU     66.16           clear sky
# 17       91            Camabatela      AO     63.43     overcast clouds
# 18      113       Plettenberg Bay      ZA     62.51           clear sky
# 19      120              Flinders      AU     63.37           clear sky
# 20      121              Ngunguru      NZ     62.17     overcast clouds
# 21      126           Port Alfred      ZA     68.90    scattered clouds
# 22      134          Ponta Do Sol      PT     67.71    scattered clouds
# 23      140               Mattawa      US     66.72     overcast clouds
# 24      148                  Tura      IN     63.50    scattered clouds
# 25      150                Gorgan      IR     62.56     overcast clouds
# 26      153        Port Elizabeth      ZA     69.10           clear sky
# 27      158             Carnarvon      AU     68.07    scattered clouds
# 28      159               Iquique      CL     68.04       broken clouds
# 29      163          Kruisfontein      ZA     66.88          light rain
# 30      174                  Chuy      UY     68.77    scattered clouds
# 31      177                  Jalu      LY     60.93       broken clouds
# 32      179           East London      ZA     69.46    scattered clouds
# 33      181                 Ancud      CL     61.43     overcast clouds
# 34      185                Talaja      IN     68.43       moderate rain
# 35      192                Mehran      IR     69.28     overcast clouds
# 36      202            Casablanca      MA     61.02          few clouds
# 37      207            Nouadhibou      MR     69.78           clear sky
# 38      221               Ballina      AU     68.77     overcast clouds
# 39      223                  Kaeo      NZ     62.33     overcast clouds
# 40      225                 Tanda      IN     65.66     overcast clouds
# 41      226                 Okato      NZ     62.42     overcast clouds
# 42      235             Geraldton      AU     61.21    scattered clouds
# 43      240  Vila Franca Do Campo      PT     67.19       broken clouds
# 44      248          Saint George      US     65.35           clear sky
# 45      254                Taltal      CL     66.97           clear sky
# 46      255        Ribeira Grande      PT     64.80       broken clouds
# 47      259                 Lagoa      PT     62.80    scattered clouds
# 48      279           Phitsanulok      TH     65.70    scattered clouds
# 49      284      Praia Da Vitoria      PT     64.76    scattered clouds
#
#         Lat       Lng                                      Hotel Name
# 0   34.8014 -106.5436                              TumbleWeed RV Park
# 1  -32.7167  152.1500                               Mantra Nelson Bay
# 2  -34.5322   20.0403                        Bredasdorp Country Manor
# 3   22.2855  114.1577                              Mini Hotel Central
# 4  -31.4333  152.9167                           Rydges Port Macquarie
# 5  -33.9258   18.4232               Southern Sun Waterfront Cape Town
# 6  -37.6167  -73.6500                                Hostal Las Lilas
# 7  -38.0023  -57.5575                        Gran Hotel Mar del Plata
# 8   -8.9266  125.4092                                  Juvinal Martin
# 9  -42.8794  147.3294                        Mantra on Collins Hobart
# 10  34.6959   44.9661                                      Layla jasm
# 11  25.0333   91.6667                         Hotel Sadi Internationl
# 12  34.6087  -98.3903   Holiday Inn Express & Suites Lawton-Fort Sill
# 13 -23.7000  133.8833                      Desert Palms Alice Springs
# 14 -34.4187   19.2345                      Misty Waves Boutique Hotel
# 15  19.2667   84.9167                            Gopalpur Palm Resort
# 16 -34.2000  142.1500                           Mercure Hotel Mildura
# 17  -8.1881   15.3750                           Pensão E Restaurantes
# 18 -34.0527   23.3716                                Thanda Vista B&B
# 19 -34.5833  150.8552         Shellharbour Resort & Conference Centre
# 20 -35.6167  174.5000                 Pacific Rendezvous Motel Resort
# 21 -33.5906   26.8910                              The Halyards Hotel
# 22  32.6667  -17.1000                                  Hotel do Campo
# 23  46.7379 -119.9028                     Sun & Sand Mobile Home Park
# 24  25.5198   90.2201                        Hotel RIKMAN Continental
# 25  36.8387   54.4348                                   Khayyam Motel
# 26 -33.9180   25.5701                          39 On Nile Guest House
# 27 -24.8667  113.6333                           Hospitality Carnarvon
# 28 -20.2208  -70.1431                     Backpacker`s Hostel Iquique
# 29 -34.0033   24.7314                         Oyster Bay House Rental
# 30 -33.6971  -53.4616                               Nuevo Hotel Plaza
# 31  29.0331   21.5482                                   صاحبة الفخامة
# 32 -33.0153   27.9116                                         Tu Casa
# 33 -41.8697  -73.8203                              Hotel Arena Gruesa
# 34  21.3500   72.0500                               Velvettas Resorts
# 35  33.1222   46.1646                                بوتیک زنانه بهار
# 36  33.5928   -7.6192                    فندق البيت المغربي كازبلانكا
# 37  20.9310  -17.0347                                       El Medina
# 38 -28.8667  153.5667  Ramada Hotel & Suites by Wyndham Ballina Byron
# 39 -35.1000  173.7833                                   Bushido Lodge
# 40  26.5500   82.6500                               MUMTAZ GANJ TANDA
# 41 -39.2000  173.8833                           Goodin Country Garden
# 42 -28.7667  114.6000                       Broadwater Mariner Resort
# 43  37.7167  -25.4333                             Pestana Bahia Praia
# 44  37.1041 -113.5841                     Best Western Plus Abbey Inn
# 45 -25.4000  -70.4833                              Residencial Karime
# 46  38.5167  -28.7000                             Quinta da Meia Eira
# 47  39.0500  -27.9833                                  Casa Das Faias
# 48  16.9167  100.5000                             บ้านโนบิตะ พิษณุโลก
# 49  38.7333  -27.0667                                  Hotel Branco I

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt>{Weather Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
# 4b. Display the figure
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
fig.add_layer(marker_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"]== "Meadow Lake"]
vacation_end = vacation_df.loc[vacation_df["City"]== "Meadow Lake"]
vacation_stop1 = vacation_df.loc[vacation_df["City"]== "Green River"]
vacation_stop2 = vacation_df.loc[vacation_df["City"]== "Mattawa"] 
vacation_stop3 = vacation_df.loc[vacation_df["City"]=="Pittsburg"]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]

stop1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
stop2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
stop3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
vacation_itinerary = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')

fig.add_layer(vacation_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3, vacation_end],ignore_index=True)
itinerary_df
# Out:
#    City_ID         City Country  Max Temp Weather Description      Lat  \
# 0        0  Meadow Lake      US     63.61          few clouds  34.8014
# 1      539  Green River      US     60.15          few clouds  41.5286
# 2      140      Mattawa      US     66.72     overcast clouds  46.7379
# 3      323    Pittsburg      US     67.66           clear sky  38.0280
# 4        0  Meadow Lake      US     63.61          few clouds  34.8014
#
#         Lng                        Hotel Name
# 0 -106.5436                TumbleWeed RV Park
# 1 -109.4662  Hampton Inn & Suites Green River
# 2 -119.9028       Sun & Sand Mobile Home Park
# 3 -121.8847    Hampton Inn & Suites Pittsburg
# 4 -106.5436                TumbleWeed RV Park

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt>{Weather Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
# 11b. Display the figure
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
fig.add_layer(marker_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

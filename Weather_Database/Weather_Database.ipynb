# %%
#Import the dependencies
import pandas as pd
import numpy as np
import time
from datetime import datetime
#citipy
from citipy import citipy

# %%
#import requests library and API key
import requests
from config import weather_api_key

# %%
# Start URL for weather API call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# creating a set of 2000 latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# create a list of lats/longs to release them from the zip
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 723

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_description})
                          
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | meadow lake
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | nelson bay
# Processing Record 4 of Set 1 | skuodas
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | kosa
# Processing Record 8 of Set 1 | leshukonskoye
# Processing Record 9 of Set 1 | severo-kurilsk
# Processing Record 10 of Set 1 | berlevag
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | iquitos
# Processing Record 13 of Set 1 | mayo
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | slobodskoy
# Processing Record 16 of Set 1 | victoria
# Processing Record 17 of Set 1 | port macquarie
# Processing Record 18 of Set 1 | biak
# Processing Record 19 of Set 1 | cherskiy
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | longyearbyen
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | fengcheng
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | portland
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | tasiilaq
# Processing Record 29 of Set 1 | cockburn harbour
# City not found. Skipping...
# Processing Record 30 of Set 1 | la ronge
# Processing Record 31 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 1 | lebu
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | airai
# Processing Record 35 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 1 | zhezkazgan
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | bengkulu
# Processing Record 39 of Set 1 | grindavik
# Processing Record 40 of Set 1 | kalmunai
# Processing Record 41 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 1 | twentynine palms
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | beloha
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | kirakira
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | kifri
# Processing Record 50 of Set 1 | chhatak
# Processing Record 1 of Set 2 | nikolskoye
# Processing Record 2 of Set 2 | biltine
# Processing Record 3 of Set 2 | goderich
# Processing Record 4 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 2 | bolkhov
# Processing Record 6 of Set 2 | tiksi
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | tazovskiy
# Processing Record 9 of Set 2 | ginda
# Processing Record 10 of Set 2 | bambous virieux
# Processing Record 11 of Set 2 | katsuura
# Processing Record 12 of Set 2 | honiara
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | ler
# Processing Record 15 of Set 2 | lawton
# Processing Record 16 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 2 | nhulunbuy
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | alice springs
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | kununurra
# Processing Record 22 of Set 2 | guerrero negro
# Processing Record 23 of Set 2 | talara
# Processing Record 24 of Set 2 | aklavik
# Processing Record 25 of Set 2 | gopalpur
# Processing Record 26 of Set 2 | san cristobal
# Processing Record 27 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 2 | caravelas
# Processing Record 29 of Set 2 | mildura
# Processing Record 30 of Set 2 | punta arenas
# Processing Record 31 of Set 2 | walvis bay
# Processing Record 32 of Set 2 | tyubuk
# Processing Record 33 of Set 2 | marsh harbour
# Processing Record 34 of Set 2 | saint-francois
# Processing Record 35 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 2 | ibimirim
# Processing Record 37 of Set 2 | baiersbronn
# Processing Record 38 of Set 2 | tulum
# Processing Record 39 of Set 2 | buala
# Processing Record 40 of Set 2 | korsakov
# Processing Record 41 of Set 2 | mantenopolis
# Processing Record 42 of Set 2 | fortuna
# Processing Record 43 of Set 2 | bluff
# Processing Record 44 of Set 2 | barreirinhas
# Processing Record 45 of Set 2 | leiyang
# Processing Record 46 of Set 2 | motygino
# Processing Record 47 of Set 2 | torbay
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | barrow
# Processing Record 50 of Set 2 | camabatela
# Processing Record 1 of Set 3 | bonavista
# Processing Record 2 of Set 3 | sukhobuzimskoye
# Processing Record 3 of Set 3 | luderitz
# Processing Record 4 of Set 3 | leh
# Processing Record 5 of Set 3 | yellowknife
# Processing Record 6 of Set 3 | srednekolymsk
# Processing Record 7 of Set 3 | khatanga
# Processing Record 8 of Set 3 | sur
# Processing Record 9 of Set 3 | balkanabat
# Processing Record 10 of Set 3 | bathsheba
# Processing Record 11 of Set 3 | alofi
# Processing Record 12 of Set 3 | new norfolk
# Processing Record 13 of Set 3 | faanui
# Processing Record 14 of Set 3 | enshi
# Processing Record 15 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 3 | steinbach
# Processing Record 17 of Set 3 | clonmel
# Processing Record 18 of Set 3 | wichita falls
# Processing Record 19 of Set 3 | okhotsk
# Processing Record 20 of Set 3 | lorengau
# Processing Record 21 of Set 3 | oistins
# Processing Record 22 of Set 3 | kodiak
# Processing Record 23 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 3 | plettenberg bay
# Processing Record 25 of Set 3 | cidreira
# Processing Record 26 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 3 | lushunkou
# City not found. Skipping...
# Processing Record 28 of Set 3 | kawana waters
# City not found. Skipping...
# Processing Record 29 of Set 3 | richards bay
# Processing Record 30 of Set 3 | valdepenas
# Processing Record 31 of Set 3 | husavik
# Processing Record 32 of Set 3 | souillac
# Processing Record 33 of Set 3 | bethel
# Processing Record 34 of Set 3 | flinders
# Processing Record 35 of Set 3 | ngunguru
# Processing Record 36 of Set 3 | tuatapere
# Processing Record 37 of Set 3 | lebork
# Processing Record 38 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 3 | rincon
# Processing Record 40 of Set 3 | normandin
# Processing Record 41 of Set 3 | port alfred
# Processing Record 42 of Set 3 | barabinsk
# Processing Record 43 of Set 3 | olinda
# Processing Record 44 of Set 3 | oktyabrskiy
# Processing Record 45 of Set 3 | maniitsoq
# Processing Record 46 of Set 3 | xining
# Processing Record 47 of Set 3 | cabo san lucas
# Processing Record 48 of Set 3 | royan
# Processing Record 49 of Set 3 | ponta do sol
# Processing Record 50 of Set 3 | amapa
# Processing Record 1 of Set 4 | hobyo
# Processing Record 2 of Set 4 | lashio
# Processing Record 3 of Set 4 | port-gentil
# Processing Record 4 of Set 4 | juegang
# Processing Record 5 of Set 4 | mattawa
# Processing Record 6 of Set 4 | el ejido
# Processing Record 7 of Set 4 | road town
# Processing Record 8 of Set 4 | pevek
# Processing Record 9 of Set 4 | makat
# Processing Record 10 of Set 4 | teya
# Processing Record 11 of Set 4 | georgetown
# Processing Record 12 of Set 4 | merauke
# Processing Record 13 of Set 4 | tura
# Processing Record 14 of Set 4 | leningradskiy
# Processing Record 15 of Set 4 | gorgan
# Processing Record 16 of Set 4 | westlock
# Processing Record 17 of Set 4 | noumea
# Processing Record 18 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 4 | port elizabeth
# Processing Record 20 of Set 4 | lompoc
# Processing Record 21 of Set 4 | lexington
# Processing Record 22 of Set 4 | kavaratti
# Processing Record 23 of Set 4 | narsaq
# Processing Record 24 of Set 4 | carnarvon
# Processing Record 25 of Set 4 | iquique
# Processing Record 26 of Set 4 | araouane
# Processing Record 27 of Set 4 | zyryanka
# Processing Record 28 of Set 4 | pocatello
# Processing Record 29 of Set 4 | kruisfontein
# Processing Record 30 of Set 4 | tuktoyaktuk
# Processing Record 31 of Set 4 | los chiles
# Processing Record 32 of Set 4 | puerto leguizamo
# Processing Record 33 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 4 | memmingen
# Processing Record 35 of Set 4 | lata
# Processing Record 36 of Set 4 | vao
# Processing Record 37 of Set 4 | hami
# Processing Record 38 of Set 4 | hambantota
# Processing Record 39 of Set 4 | pochutla
# Processing Record 40 of Set 4 | navahrudak
# Processing Record 41 of Set 4 | chuy
# Processing Record 42 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 4 | santarem
# Processing Record 44 of Set 4 | jibuti
# Processing Record 45 of Set 4 | jalu
# Processing Record 46 of Set 4 | kalengwa
# Processing Record 47 of Set 4 | east london
# Processing Record 48 of Set 4 | zavetnoye
# Processing Record 49 of Set 4 | ancud
# Processing Record 50 of Set 4 | gonzales
# Processing Record 1 of Set 5 | adrar
# Processing Record 2 of Set 5 | qaanaaq
# Processing Record 3 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 of Set 5 | talaja
# Processing Record 5 of Set 5 | san quintin
# Processing Record 6 of Set 5 | manzhouli
# Processing Record 7 of Set 5 | dzhebariki-khaya
# Processing Record 8 of Set 5 | svetlogorsk
# Processing Record 9 of Set 5 | hervey bay
# Processing Record 10 of Set 5 | sorrento
# Processing Record 11 of Set 5 | mehran
# Processing Record 12 of Set 5 | tambul
# City not found. Skipping...
# Processing Record 13 of Set 5 | homer
# Processing Record 14 of Set 5 | ribera
# Processing Record 15 of Set 5 | tarragona
# Processing Record 16 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 5 | ordzhonikidze
# Processing Record 18 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 5 | sambava
# Processing Record 20 of Set 5 | tashtagol
# Processing Record 21 of Set 5 | ilebo
# Processing Record 22 of Set 5 | kutum
# Processing Record 23 of Set 5 | mairana
# Processing Record 24 of Set 5 | casablanca
# Processing Record 25 of Set 5 | lakselv
# Processing Record 26 of Set 5 | tabou
# Processing Record 27 of Set 5 | mukhen
# Processing Record 28 of Set 5 | saskylakh
# Processing Record 29 of Set 5 | nouadhibou
# Processing Record 30 of Set 5 | obigarm
# Processing Record 31 of Set 5 | kibala
# Processing Record 32 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 5 | arraial do cabo
# Processing Record 34 of Set 5 | zhigansk
# Processing Record 35 of Set 5 | zhanaozen
# Processing Record 36 of Set 5 | gizo
# Processing Record 37 of Set 5 | kabin buri
# Processing Record 38 of Set 5 | margate
# Processing Record 39 of Set 5 | hithadhoo
# Processing Record 40 of Set 5 | poum
# Processing Record 41 of Set 5 | strelice
# Processing Record 42 of Set 5 | xichang
# Processing Record 43 of Set 5 | kirkwall
# Processing Record 44 of Set 5 | ballina
# Processing Record 45 of Set 5 | kusk
# City not found. Skipping...
# Processing Record 46 of Set 5 | acarau
# Processing Record 47 of Set 5 | kaeo
# Processing Record 48 of Set 5 | soria
# Processing Record 49 of Set 5 | tanda
# Processing Record 50 of Set 5 | okato
# Processing Record 1 of Set 6 | novoagansk
# Processing Record 2 of Set 6 | solnechnyy
# Processing Record 3 of Set 6 | mareeba
# Processing Record 4 of Set 6 | vardo
# Processing Record 5 of Set 6 | makokou
# Processing Record 6 of Set 6 | derzhavinsk
# Processing Record 7 of Set 6 | myszkow
# Processing Record 8 of Set 6 | santa isabel do rio negro
# Processing Record 9 of Set 6 | geraldton
# Processing Record 10 of Set 6 | qaqortoq
# Processing Record 11 of Set 6 | erzurum
# Processing Record 12 of Set 6 | yeppoon
# Processing Record 13 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 14 of Set 6 | newark
# Processing Record 15 of Set 6 | vila franca do campo
# Processing Record 16 of Set 6 | oskarshamn
# Processing Record 17 of Set 6 | mehamn
# Processing Record 18 of Set 6 | haines junction
# Processing Record 19 of Set 6 | codrington
# Processing Record 20 of Set 6 | sorong
# Processing Record 21 of Set 6 | coihaique
# Processing Record 22 of Set 6 | aswan
# Processing Record 23 of Set 6 | saint george
# Processing Record 24 of Set 6 | esperance
# Processing Record 25 of Set 6 | mount gambier
# Processing Record 26 of Set 6 | kapoeta
# Processing Record 27 of Set 6 | oskemen
# Processing Record 28 of Set 6 | houston
# Processing Record 29 of Set 6 | taltal
# Processing Record 30 of Set 6 | ribeira grande
# Processing Record 31 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 6 | clyde river
# Processing Record 33 of Set 6 | dolzhanskaya
# Processing Record 34 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 35 of Set 6 | laguna
# Processing Record 36 of Set 6 | lagoa
# Processing Record 37 of Set 6 | upernavik
# Processing Record 38 of Set 6 | bedum
# Processing Record 39 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 40 of Set 6 | dakar
# Processing Record 41 of Set 6 | iqaluit
# Processing Record 42 of Set 6 | altay
# Processing Record 43 of Set 6 | nyurba
# Processing Record 44 of Set 6 | kwinana
# Processing Record 45 of Set 6 | scalloway
# City not found. Skipping...
# Processing Record 46 of Set 6 | bocana de paiwas
# Processing Record 47 of Set 6 | todos santos
# Processing Record 48 of Set 6 | korla
# Processing Record 49 of Set 6 | zaton
# Processing Record 50 of Set 6 | rio grande
# Processing Record 1 of Set 7 | port blair
# Processing Record 2 of Set 7 | artigas
# Processing Record 3 of Set 7 | jacksonville
# Processing Record 4 of Set 7 | vila velha
# Processing Record 5 of Set 7 | saldus
# Processing Record 6 of Set 7 | holeby
# Processing Record 7 of Set 7 | torrington
# Processing Record 8 of Set 7 | phitsanulok
# Processing Record 9 of Set 7 | ilulissat
# Processing Record 10 of Set 7 | popondetta
# Processing Record 11 of Set 7 | channel-port aux basques
# Processing Record 12 of Set 7 | san patricio
# Processing Record 13 of Set 7 | praia da vitoria
# Processing Record 14 of Set 7 | dingle
# Processing Record 15 of Set 7 | gambela
# Processing Record 16 of Set 7 | addis abeba
# Processing Record 17 of Set 7 | kashi
# Processing Record 18 of Set 7 | pechora
# Processing Record 19 of Set 7 | yenagoa
# Processing Record 20 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 7 | sovetskiy
# Processing Record 22 of Set 7 | boffa
# Processing Record 23 of Set 7 | beira
# Processing Record 24 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 25 of Set 7 | provideniya
# Processing Record 26 of Set 7 | astoria
# Processing Record 27 of Set 7 | ahipara
# Processing Record 28 of Set 7 | tchollire
# Processing Record 29 of Set 7 | dikson
# Processing Record 30 of Set 7 | areia branca
# Processing Record 31 of Set 7 | tornio
# Processing Record 32 of Set 7 | carutapera
# Processing Record 33 of Set 7 | namatanai
# Processing Record 34 of Set 7 | mahebourg
# Processing Record 35 of Set 7 | cockburn town
# Processing Record 36 of Set 7 | rio verde de mato grosso
# Processing Record 37 of Set 7 | puerto baquerizo moreno
# Processing Record 38 of Set 7 | akdepe
# Processing Record 39 of Set 7 | touros
# Processing Record 40 of Set 7 | robertsport
# Processing Record 41 of Set 7 | dien bien
# City not found. Skipping...
# Processing Record 42 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 43 of Set 7 | tenenkou
# Processing Record 44 of Set 7 | altamira
# Processing Record 45 of Set 7 | ponta delgada
# Processing Record 46 of Set 7 | muravlenko
# Processing Record 47 of Set 7 | kloulklubed
# Processing Record 48 of Set 7 | kissidougou
# Processing Record 49 of Set 7 | bacolod
# Processing Record 50 of Set 7 | bilma
# Processing Record 1 of Set 8 | college
# Processing Record 2 of Set 8 | arman
# Processing Record 3 of Set 8 | broken hill
# Processing Record 4 of Set 8 | salalah
# Processing Record 5 of Set 8 | turtas
# Processing Record 6 of Set 8 | pittsburg
# Processing Record 7 of Set 8 | fairbanks
# Processing Record 8 of Set 8 | blairmore
# Processing Record 9 of Set 8 | stromness
# Processing Record 10 of Set 8 | hasaki
# Processing Record 11 of Set 8 | cayenne
# Processing Record 12 of Set 8 | mandalgovi
# Processing Record 13 of Set 8 | komsomolskiy
# Processing Record 14 of Set 8 | maumere
# Processing Record 15 of Set 8 | ihosy
# Processing Record 16 of Set 8 | cilegon
# Processing Record 17 of Set 8 | saldanha
# Processing Record 18 of Set 8 | umm kaddadah
# Processing Record 19 of Set 8 | santa maria
# Processing Record 20 of Set 8 | baglung
# Processing Record 21 of Set 8 | kavieng
# Processing Record 22 of Set 8 | shchigry
# Processing Record 23 of Set 8 | zapolyarnyy
# Processing Record 24 of Set 8 | lamar
# Processing Record 25 of Set 8 | pangnirtung
# Processing Record 26 of Set 8 | general roca
# Processing Record 27 of Set 8 | mount pleasant
# Processing Record 28 of Set 8 | roald
# Processing Record 29 of Set 8 | victoria point
# Processing Record 30 of Set 8 | mantua
# Processing Record 31 of Set 8 | tahta
# Processing Record 32 of Set 8 | ialibu
# Processing Record 33 of Set 8 | marsa matruh
# Processing Record 34 of Set 8 | serra talhada
# Processing Record 35 of Set 8 | norman wells
# Processing Record 36 of Set 8 | boguchany
# Processing Record 37 of Set 8 | khor
# Processing Record 38 of Set 8 | quatre cocos
# Processing Record 39 of Set 8 | rocha
# Processing Record 40 of Set 8 | corralillo
# Processing Record 41 of Set 8 | padang
# Processing Record 42 of Set 8 | bonthe
# Processing Record 43 of Set 8 | tilichiki
# Processing Record 44 of Set 8 | chokurdakh
# Processing Record 45 of Set 8 | gizycko
# Processing Record 46 of Set 8 | hofn
# Processing Record 47 of Set 8 | pniv
# Processing Record 48 of Set 8 | ligayan
# Processing Record 49 of Set 8 | camargo
# Processing Record 50 of Set 8 | constitucion
# Processing Record 1 of Set 9 | mahon
# Processing Record 2 of Set 9 | nanchong
# Processing Record 3 of Set 9 | nonantola
# Processing Record 4 of Set 9 | sorland
# Processing Record 5 of Set 9 | shieli
# Processing Record 6 of Set 9 | omsukchan
# Processing Record 7 of Set 9 | thap than
# Processing Record 8 of Set 9 | tiznit
# Processing Record 9 of Set 9 | nemuro
# Processing Record 10 of Set 9 | tateyama
# Processing Record 11 of Set 9 | broome
# Processing Record 12 of Set 9 | stonewall
# Processing Record 13 of Set 9 | taoudenni
# Processing Record 14 of Set 9 | atar
# Processing Record 15 of Set 9 | san vicente
# Processing Record 16 of Set 9 | yellamanchili
# City not found. Skipping...
# Processing Record 17 of Set 9 | necochea
# Processing Record 18 of Set 9 | pitimbu
# Processing Record 19 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 9 | hammond
# Processing Record 21 of Set 9 | khani
# Processing Record 22 of Set 9 | ankazoabo
# Processing Record 23 of Set 9 | bilecik
# Processing Record 24 of Set 9 | notodden
# Processing Record 25 of Set 9 | beringovskiy
# Processing Record 26 of Set 9 | katobu
# Processing Record 27 of Set 9 | barao de melgaco
# Processing Record 28 of Set 9 | santa teresa
# Processing Record 29 of Set 9 | bandarban
# Processing Record 30 of Set 9 | matara
# Processing Record 31 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 9 | dayong
# Processing Record 33 of Set 9 | klaksvik
# Processing Record 34 of Set 9 | bontang
# Processing Record 35 of Set 9 | denpasar
# Processing Record 36 of Set 9 | saraland
# Processing Record 37 of Set 9 | grand-lahou
# Processing Record 38 of Set 9 | olafsvik
# Processing Record 39 of Set 9 | terrace
# Processing Record 40 of Set 9 | alta floresta
# Processing Record 41 of Set 9 | banjar
# Processing Record 42 of Set 9 | yar-sale
# Processing Record 43 of Set 9 | aripuana
# Processing Record 44 of Set 9 | pisco
# Processing Record 45 of Set 9 | zambezi
# Processing Record 46 of Set 9 | hovd
# Processing Record 47 of Set 9 | sitka
# Processing Record 48 of Set 9 | eregli
# Processing Record 49 of Set 9 | moose factory
# Processing Record 50 of Set 9 | lubango
# Processing Record 1 of Set 10 | mocuba
# Processing Record 2 of Set 10 | isiolo
# Processing Record 3 of Set 10 | ust-kuyga
# Processing Record 4 of Set 10 | sirari
# Processing Record 5 of Set 10 | khudumelapye
# Processing Record 6 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 7 of Set 10 | saint-martin-boulogne
# Processing Record 8 of Set 10 | beisfjord
# Processing Record 9 of Set 10 | labuhan
# Processing Record 10 of Set 10 | nanesti
# Processing Record 11 of Set 10 | pulaski
# Processing Record 12 of Set 10 | adigeni
# Processing Record 13 of Set 10 | mouzakion
# City not found. Skipping...
# Processing Record 14 of Set 10 | hisor
# Processing Record 15 of Set 10 | pasighat
# Processing Record 16 of Set 10 | telimele
# Processing Record 17 of Set 10 | kampong cham
# Processing Record 18 of Set 10 | gravdal
# Processing Record 19 of Set 10 | asau
# Processing Record 20 of Set 10 | nakamura
# Processing Record 21 of Set 10 | kamenka
# Processing Record 22 of Set 10 | mogadishu
# Processing Record 23 of Set 10 | sistranda
# Processing Record 24 of Set 10 | tha chang
# Processing Record 25 of Set 10 | kasongo-lunda
# Processing Record 26 of Set 10 | pacific grove
# Processing Record 27 of Set 10 | marfino
# Processing Record 28 of Set 10 | isangel
# Processing Record 29 of Set 10 | montrose
# Processing Record 30 of Set 10 | brokopondo
# Processing Record 31 of Set 10 | sept-iles
# Processing Record 32 of Set 10 | linkuva
# Processing Record 33 of Set 10 | bernardino de campos
# Processing Record 34 of Set 10 | hirado
# Processing Record 35 of Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 10 | nokaneng
# Processing Record 37 of Set 10 | gemena
# Processing Record 38 of Set 10 | umm bab
# Processing Record 39 of Set 10 | mauswagon
# City not found. Skipping...
# Processing Record 40 of Set 10 | kaitangata
# Processing Record 41 of Set 10 | owerri
# Processing Record 42 of Set 10 | aksu
# Processing Record 43 of Set 10 | san andres
# Processing Record 44 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 46 of Set 10 | baturaja
# Processing Record 47 of Set 10 | sabang
# Processing Record 48 of Set 10 | udachnyy
# Processing Record 49 of Set 10 | nishihara
# Processing Record 50 of Set 10 | sakakah
# Processing Record 1 of Set 11 | holland
# Processing Record 2 of Set 11 | borba
# Processing Record 3 of Set 11 | okha
# Processing Record 4 of Set 11 | avera
# Processing Record 5 of Set 11 | severo-yeniseyskiy
# Processing Record 6 of Set 11 | kyren
# Processing Record 7 of Set 11 | umm lajj
# Processing Record 8 of Set 11 | riyadh
# Processing Record 9 of Set 11 | weiser
# Processing Record 10 of Set 11 | tucuman
# Processing Record 11 of Set 11 | porrentruy
# Processing Record 12 of Set 11 | araucaria
# Processing Record 13 of Set 11 | dolinsk
# Processing Record 14 of Set 11 | harnosand
# Processing Record 15 of Set 11 | dzilam gonzalez
# Processing Record 16 of Set 11 | kudahuvadhoo
# Processing Record 17 of Set 11 | novikovo
# Processing Record 18 of Set 11 | dunedin
# Processing Record 19 of Set 11 | samarai
# Processing Record 20 of Set 11 | inhambane
# Processing Record 21 of Set 11 | bud
# Processing Record 22 of Set 11 | manaus
# Processing Record 23 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 24 of Set 11 | pathein
# Processing Record 25 of Set 11 | chernyakhovsk
# Processing Record 26 of Set 11 | puri
# Processing Record 27 of Set 11 | raudeberg
# Processing Record 28 of Set 11 | yumen
# Processing Record 29 of Set 11 | zhangye
# Processing Record 30 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 31 of Set 11 | monrovia
# Processing Record 32 of Set 11 | luganville
# Processing Record 33 of Set 11 | borujerd
# Processing Record 34 of Set 11 | sao filipe
# Processing Record 35 of Set 11 | koindu
# Processing Record 36 of Set 11 | kushima
# Processing Record 37 of Set 11 | kahului
# Processing Record 38 of Set 11 | tres arroyos
# Processing Record 39 of Set 11 | cranbrook
# Processing Record 40 of Set 11 | kostino
# Processing Record 41 of Set 11 | hamadan
# Processing Record 42 of Set 11 | tshikapa
# Processing Record 43 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 44 of Set 11 | belmonte
# Processing Record 45 of Set 11 | los llanos de aridane
# Processing Record 46 of Set 11 | rawson
# Processing Record 47 of Set 11 | ust-omchug
# Processing Record 48 of Set 11 | doka
# Processing Record 49 of Set 11 | maragogi
# Processing Record 50 of Set 11 | bam
# Processing Record 1 of Set 12 | mazatlan
# Processing Record 2 of Set 12 | puerto del rosario
# Processing Record 3 of Set 12 | santo antonio do ica
# Processing Record 4 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 12 | north haven
# Processing Record 6 of Set 12 | kenai
# Processing Record 7 of Set 12 | coquimbo
# Processing Record 8 of Set 12 | zemio
# Processing Record 9 of Set 12 | lazaro cardenas
# Processing Record 10 of Set 12 | ust-tsilma
# Processing Record 11 of Set 12 | sangar
# Processing Record 12 of Set 12 | nadym
# Processing Record 13 of Set 12 | bukene
# Processing Record 14 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 12 | belousovka
# Processing Record 16 of Set 12 | acapulco
# Processing Record 17 of Set 12 | talnakh
# Processing Record 18 of Set 12 | waddan
# Processing Record 19 of Set 12 | banepa
# Processing Record 20 of Set 12 | le port
# Processing Record 21 of Set 12 | vytegra
# Processing Record 22 of Set 12 | suluq
# Processing Record 23 of Set 12 | aguimes
# Processing Record 24 of Set 12 | ellington
# Processing Record 25 of Set 12 | guacimo
# Processing Record 26 of Set 12 | kalamata
# Processing Record 27 of Set 12 | harstad
# Processing Record 28 of Set 12 | wajima
# Processing Record 29 of Set 12 | divnogorsk
# Processing Record 30 of Set 12 | vung tau
# Processing Record 31 of Set 12 | yelizovo
# Processing Record 32 of Set 12 | rundu
# Processing Record 33 of Set 12 | puerto asis
# Processing Record 34 of Set 12 | bafra
# Processing Record 35 of Set 12 | tamandare
# Processing Record 36 of Set 12 | green river
# Processing Record 37 of Set 12 | vestmannaeyjar
# Processing Record 38 of Set 12 | sumenep
# Processing Record 39 of Set 12 | stolin
# Processing Record 40 of Set 12 | sisimiut
# Processing Record 41 of Set 12 | balaipungut
# Processing Record 42 of Set 12 | camacha
# Processing Record 43 of Set 12 | petrokamenskoye
# Processing Record 44 of Set 12 | abomsa
# Processing Record 45 of Set 12 | kabanjahe
# Processing Record 46 of Set 12 | kharan
# Processing Record 47 of Set 12 | kant
# Processing Record 48 of Set 12 | aasiaat
# Processing Record 49 of Set 12 | sungaipenuh
# Processing Record 50 of Set 12 | xai-xai
# Processing Record 1 of Set 13 | iroquois falls
# Processing Record 2 of Set 13 | mwanza
# Processing Record 3 of Set 13 | mount isa
# Processing Record 4 of Set 13 | taunggyi
# Processing Record 5 of Set 13 | taksimo
# Processing Record 6 of Set 13 | nisia floresta
# Processing Record 7 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 13 | strezhevoy
# Processing Record 9 of Set 13 | yerbogachen
# Processing Record 10 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 13 | shingu
# Processing Record 12 of Set 13 | havelock
# Processing Record 13 of Set 13 | elizabeth city
# Processing Record 14 of Set 13 | mahibadhoo
# Processing Record 15 of Set 13 | port lincoln
# Processing Record 16 of Set 13 | puebla
# Processing Record 17 of Set 13 | gat
# Processing Record 18 of Set 13 | bubaque
# Processing Record 19 of Set 13 | vattalkundu
# Processing Record 20 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 21 of Set 13 | awbari
# Processing Record 22 of Set 13 | jepara
# Processing Record 23 of Set 13 | buza
# Processing Record 24 of Set 13 | fare
# Processing Record 25 of Set 13 | boden
# Processing Record 26 of Set 13 | talaya
# Processing Record 27 of Set 13 | flin flon
# Processing Record 28 of Set 13 | salinopolis
# Processing Record 29 of Set 13 | te anau
# Processing Record 30 of Set 13 | tokur
# Processing Record 31 of Set 13 | buraydah
# Processing Record 32 of Set 13 | santiago
# Processing Record 33 of Set 13 | ximei
# Processing Record 34 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 13 | tual
# Processing Record 36 of Set 13 | karratha
# Processing Record 37 of Set 13 | tromso
# Processing Record 38 of Set 13 | soyo
# Processing Record 39 of Set 13 | charters towers
# Processing Record 40 of Set 13 | shelabolikha
# Processing Record 41 of Set 13 | meulaboh
# Processing Record 42 of Set 13 | tanout
# Processing Record 43 of Set 13 | champerico
# Processing Record 44 of Set 13 | saint andrews
# Processing Record 45 of Set 13 | sturgis
# Processing Record 46 of Set 13 | point pleasant
# Processing Record 47 of Set 13 | puerto madero
# Processing Record 48 of Set 13 | mangai
# Processing Record 49 of Set 13 | paramonga
# Processing Record 50 of Set 13 | talcahuano
# Processing Record 1 of Set 14 | nabire
# Processing Record 2 of Set 14 | erenhot
# Processing Record 3 of Set 14 | monywa
# Processing Record 4 of Set 14 | verkhnevilyuysk
# Processing Record 5 of Set 14 | lubumbashi
# Processing Record 6 of Set 14 | reporoa
# Processing Record 7 of Set 14 | changping
# Processing Record 8 of Set 14 | najran
# Processing Record 9 of Set 14 | nanning
# Processing Record 10 of Set 14 | contamana
# Processing Record 11 of Set 14 | nanortalik
# Processing Record 12 of Set 14 | itarema
# Processing Record 13 of Set 14 | garmsar
# Processing Record 14 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 14 | slave lake
# Processing Record 16 of Set 14 | santa rosa
# Processing Record 17 of Set 14 | villa carlos paz
# Processing Record 18 of Set 14 | ritchie
# Processing Record 19 of Set 14 | morant bay
# Processing Record 20 of Set 14 | havre-saint-pierre
# Processing Record 21 of Set 14 | zabol
# Processing Record 22 of Set 14 | ipameri
# Processing Record 23 of Set 14 | tambopata
# Processing Record 24 of Set 14 | maxixe
# Processing Record 25 of Set 14 | ambilobe
# Processing Record 26 of Set 14 | faya
# Processing Record 27 of Set 14 | dukat
# Processing Record 28 of Set 14 | marawi
# Processing Record 29 of Set 14 | druzhba
# Processing Record 30 of Set 14 | iralaya
# Processing Record 31 of Set 14 | aquiraz
# Processing Record 32 of Set 14 | ust-nera
# Processing Record 33 of Set 14 | sapulpa
# Processing Record 34 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 14 | gull lake
# Processing Record 36 of Set 14 | xapuri
# Processing Record 37 of Set 14 | the pas
# Processing Record 38 of Set 14 | abu samrah
# Processing Record 39 of Set 14 | comodoro rivadavia
# Processing Record 40 of Set 14 | irtyshskiy
# Processing Record 41 of Set 14 | kismayo
# Processing Record 42 of Set 14 | lovozero
# Processing Record 43 of Set 14 | bandarbeyla
# Processing Record 44 of Set 14 | purranque
# Processing Record 45 of Set 14 | bereda
# Processing Record 46 of Set 14 | baker city
# Processing Record 47 of Set 14 | mafinga
# Processing Record 48 of Set 14 | bardiyah
# Processing Record 49 of Set 14 | northam
# Processing Record 50 of Set 14 | wewak
# Processing Record 1 of Set 15 | po
# City not found. Skipping...
# Processing Record 2 of Set 15 | guanica
# Processing Record 3 of Set 15 | bowen
# Processing Record 4 of Set 15 | nortelandia
# Processing Record 5 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 6 of Set 15 | ostrovnoy
# Processing Record 7 of Set 15 | naryan-mar
# Processing Record 8 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 15 | mikhaylovskoye
# Processing Record 10 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 11 of Set 15 | moree
# Processing Record 12 of Set 15 | campos
# Processing Record 13 of Set 15 | yamada
# Processing Record 14 of Set 15 | gondomar
# Processing Record 15 of Set 15 | bilibino
# Processing Record 16 of Set 15 | naze
# Processing Record 17 of Set 15 | maarianhamina
# Processing Record 18 of Set 15 | atasu
# Processing Record 19 of Set 15 | tibati
# Processing Record 20 of Set 15 | zelenoborskiy
# Processing Record 21 of Set 15 | kohlu
# Processing Record 22 of Set 15 | hastings
# Processing Record 23 of Set 15 | byron bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Meadow Lake      US  34.8014 -106.5436     63.61        29          21
# 1     Thompson      CA  55.7435  -97.8558      7.65        91         100
# 2   Nelson Bay      AU -32.7167  152.1500     68.00        97          76
# 3      Skuodas      LT  56.2667   21.5333     30.06        86         100
# 4   Bredasdorp      ZA -34.5322   20.0403     62.28        70          93
#
#    Wind Speed Weather Description
# 0        7.70          few clouds
# 1        9.57     overcast clouds
# 2        4.32       broken clouds
# 3        9.93     overcast clouds
# 4       11.86     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
